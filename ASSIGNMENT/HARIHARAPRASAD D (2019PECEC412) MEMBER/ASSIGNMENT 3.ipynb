# %% [markdown]
# Assignment 3

# %% [markdown]
# Problem Statement :- Build CNN Model for Classification Of Flowers

# %% [markdown]
# Unzipping the dataset

# %%
# !unzip '/content/Flowers-Dataset.zip'
# Out:
# unzip:  cannot find or open /content/Flowers-Dataset.zip, /content/Flowers-Dataset.zip.zip or /content/Flowers-Dataset.zip.ZIP.

# %% [markdown]
# Image Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
flowers_datagram = ImageDataGenerator(rescale=1./255,
                                    zoom_range=0.2,
                                    horizontal_flip=True)

# %%
flowers_datagram = ImageDataGenerator(rescale=1./255)

# %%
xflowers = flowers_datagram.flow_from_directory('/content/flowers',
                                                target_size=(64,64),
                                                class_mode='categorical',
                                                batch_size=100)
# Out:
# Found 4317 images belonging to 5 classes.

# %% [markdown]
# Create Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Convolution2D,MaxPooling2D,Flatten,Dense

# %% [markdown]
# Add Layers

# %%
model = Sequential()

# %% [markdown]
# Convolution

# %%
model.add(Convolution2D(32,(3,3),activation='relu',input_shape=(64,64,3)))

# %% [markdown]
# MaxPooling

# %%
model.add(MaxPooling2D(pool_size=(2,2)))

# %% [markdown]
# Flatten

# %%
model.add(Flatten())

# %% [markdown]
# Dense

# %%
#1st hidden layer
model.add(Dense(200,activation='relu')) 
#2nd hidden layer
model.add(Dense(100,activation='relu'))

# %% [markdown]
# Output

# %%
#Output layer
model.add(Dense(5,activation='softmax'))

# %% [markdown]
# Compile The Model

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# Fit The Model

# %%
model.fit_generator(xflowers,
                    steps_per_epoch=len(xflowers),
                    epochs=20,
                    validation_data=xflowers,
                    validation_steps=len(xflowers),)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   """
# Epoch 1/20
# 44/44 [==============================] - 39s 873ms/step - loss: 1.0626 - accuracy: 0.7287 - val_loss: 0.5209 - val_accuracy: 0.7934
# Epoch 2/20
# 44/44 [==============================] - 39s 886ms/step - loss: 0.4248 - accuracy: 0.7876 - val_loss: 0.3785 - val_accuracy: 0.7978
# Epoch 3/20
# 44/44 [==============================] - 39s 878ms/step - loss: 0.3893 - accuracy: 0.7948 - val_loss: 0.3319 - val_accuracy: 0.8110
# Epoch 4/20
# 44/44 [==============================] - 41s 935ms/step - loss: 0.1953 - accuracy: 0.9402 - val_loss: 0.0339 - val_accuracy: 0.9949
# Epoch 5/20
# 44/44 [==============================] - 42s 950ms/step - loss: 0.0727 - accuracy: 0.9831 - val_loss: 0.0330 - val_accuracy: 0.9921
# Epoch 6/20
# 44/44 [==============================] - 38s 855ms/step - loss: 0.0704 - accuracy: 0.9808 - val_loss: 0.0318 - val_accuracy: 0.9928
# Epoch 7/20
# 44/44 [==============================] - 38s 868ms/step - loss: 0.0441 - accuracy: 0.9870 - val_loss: 0.0143 - val_accuracy: 0.9977
# Epoch 8/20
# 44/44 [==============================] - 37s 852ms/step - loss: 0.0263 - accuracy: 0.9940 - val_loss: 0.0129 - val_accuracy: 0.9975
# Epoch 9/20
# 44/44 [==============================] - 37s 847ms/step - loss: 0.0529 - accuracy: 0.9845 - val_loss: 0.1093 - val_accuracy: 0.9669
# Epoch 10/20
# 44/44 [==============================] - 37s 847ms/step - loss: 0.0474 - accuracy: 0.9880 - val_loss: 0.0243 - val_accuracy: 0.9954
# Epoch 11/20
# 44/44 [==============================] - 38s 866ms/step - loss: 0.0352 - accuracy: 0.9926 - val_loss: 0.0119 - val_accuracy: 0.9986
# Epoch 12/20
# 44/44 [==============================] - 37s 848ms/step - loss: 0.0695 - accuracy: 0.9815 - val_loss: 0.0891 - val_accuracy: 0.9778
# Epoch 13/20
# 44/44 [==============================] - 37s 846ms/step - loss: 0.0737 - accuracy: 0.9817 - val_loss: 0.0190 - val_accuracy: 0.9963
# Epoch 14/20
# 44/44 [==============================] - 38s 877ms/step - loss: 0.0158 - accuracy: 0.9970 - val_loss: 0.0074 - val_accuracy: 0.9991
# Epoch 15/20
# 44/44 [==============================] - 37s 852ms/step - loss: 0.0102 - accuracy: 0.9975 - val_loss: 0.0281 - val_accuracy: 0.9933
# Epoch 16/20
# 44/44 [==============================] - 38s 860ms/step - loss: 0.0203 - accuracy: 0.9956 - val_loss: 0.0345 - val_accuracy: 0.9891
# Epoch 17/20
# 44/44 [==============================] - 40s 902ms/step - loss: 0.0281 - accuracy: 0.9905 - val_loss: 0.0665 - val_accuracy: 0.9854
# Epoch 18/20
# 44/44 [==============================] - 39s 890ms/step - loss: 0.0271 - accuracy: 0.9937 - val_loss: 0.0344 - val_accuracy: 0.9896
# Epoch 19/20
# 44/44 [==============================] - 38s 862ms/step - loss: 0.0244 - accuracy: 0.9940 - val_loss: 0.0224 - val_accuracy: 0.9947
# Epoch 20/20
# 44/44 [==============================] - 38s 858ms/step - loss: 0.0370 - accuracy: 0.9893 - val_loss: 0.0183 - val_accuracy: 0.9947

# %% [markdown]
# Save The Model

# %%
model.save('flowers.h5')

# %% [markdown]
# Test The Model

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

# %%
img= image.load_img('/content/flowers/rose/12562723334_a2e0a9e3c8_n.jpg',target_size=(200,300))
img
# Out:
# <PIL.Image.Image image mode=RGB size=300x200 at 0x7F8CA7370F10>

# %%
arr= image.img_to_array(img)
arr
# Out:
# array([[[174., 180., 204.],
#         [171., 177., 193.],
#         [170., 174., 183.],
#         ...,
#         [132., 133., 138.],
#         [140., 141., 146.],
#         [152., 151., 157.]],
#
#        [[175., 180., 202.],
#         [185., 191., 205.],
#         [201., 206., 212.],
#         ...,
#         [137., 138., 143.],
#         [143., 144., 149.],
#         [153., 152., 158.]],
#
#        [[205., 206., 224.],
#         [199., 202., 211.],
#         [205., 209., 210.],
#         ...,
#         [142., 143., 148.],
#         [146., 147., 151.],
#         [154., 153., 158.]],
#
#        ...,
#
#        [[223., 227., 194.],
#         [222., 227., 187.],
#         [221., 224., 177.],
#         ...,
#         [ 73.,  67.,  71.],
#         [114., 106., 104.],
#         [172., 165., 157.]],
#
#        [[218., 223., 182.],
#         [219., 223., 173.],
#         [220., 221., 163.],
#         ...,
#         [ 66.,  65.,  71.],
#         [ 54.,  53.,  59.],
#         [ 55.,  56.,  60.]],
#
#        [[227., 230., 187.],
#         [222., 224., 174.],
#         [219., 219., 159.],
#         ...,
#         [ 64.,  63.,  61.],
#         [ 68.,  67.,  73.],
#         [ 59.,  57.,  68.]]], dtype=float32)
